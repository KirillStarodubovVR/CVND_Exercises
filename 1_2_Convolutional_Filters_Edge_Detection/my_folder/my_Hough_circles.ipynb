# %%
import numpy as np
import matplotlib.pyplot as plt 
import cv2

# %%
image = cv2.imread("..\\images\\round_farms.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
plt.imshow(gray, cmap="gray")

# %%
blurred = cv2.GaussianBlur(gray, (7, 7), 0)
plt.imshow(blurred, cmap="gray")

# %%
circles_im = np.copy(image)

# %%
circles = cv2.HoughCircles(
    blurred, 
    cv2.HOUGH_GRADIENT, 
    1, 
    minDist=40, 
    param1=70, 
    param2=11, 
    minRadius=20, 
    maxRadius=28)

# %%
circles = np.uint16(np.around(circles))

total = 0
for i in circles[0, :]:
    cv2.circle(circles_im, (i[0], i[1]), i[2], (0, 255, 0), 2)
    cv2.circle(circles_im, (i[0], i[1]), 2, (0, 0, 255), 6)
    total += 1

plt.imshow(circles_im)
print('Circles shape: ', circles.shape)
print(f"Number of circles: {total}")
# Out:
# Circles shape:  (1, 80, 3)
# Number of circles: 80
